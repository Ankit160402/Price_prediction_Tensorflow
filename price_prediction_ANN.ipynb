# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('melb_data.csv')
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.describe().transpose()
# Out:
#                  count          mean            std          min  \
# Rooms          13580.0  2.937997e+00       0.955748      1.00000
# Price          13580.0  1.075684e+06  639310.724296  85000.00000
# Distance       13580.0  1.013778e+01       5.868725      0.00000
# Postcode       13580.0  3.105302e+03      90.676964   3000.00000
# Bedroom2       13580.0  2.914728e+00       0.965921      0.00000
# Bathroom       13580.0  1.534242e+00       0.691712      0.00000
# Car            13518.0  1.610075e+00       0.962634      0.00000
# Landsize       13580.0  5.584161e+02    3990.669241      0.00000
# BuildingArea    7130.0  1.519676e+02     541.014538      0.00000
# YearBuilt       8205.0  1.964684e+03      37.273762   1196.00000
# Lattitude      13580.0 -3.780920e+01       0.079260    -38.18255
# Longtitude     13580.0  1.449952e+02       0.103916    144.43181
# Propertycount  13580.0  7.454417e+03    4378.581772    249.00000
#
# ...

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %% [markdown]
# # Dealing with Null Data

# %%
df['BuildingArea'].fillna(value=151.9676, inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea        0
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['Car'].value_counts()
# Out:
# 2.0     5591
# 1.0     5509
# 0.0     1026
# 3.0      748
# 4.0      506
# 5.0       63
# 6.0       54
# 8.0        9
# 7.0        8
# 10.0       3
# 9.0        1
# Name: Car, dtype: int64

# %%
sb.countplot(x="Car",data=df)
# Out:
# <AxesSubplot: xlabel='Car', ylabel='count'>

# %%
df['Car'].fillna(value=1.610075, inplace=True)

# %%
df = df[df["Car"] < 5]

# %%
sb.countplot(x="Car",data=df)
# Out:
# <AxesSubplot: xlabel='Car', ylabel='count'>

# %%
df["Car"].value_counts()
# Out:
# 2.000000    5591
# 1.000000    5509
# 0.000000    1026
# 3.000000     748
# 4.000000     506
# 1.610075      62
# Name: Car, dtype: int64

# %%
df = df[df["Car"]!=1.610075]

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt        5284
# CouncilArea      1278
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['YearBuilt'].value_counts()
# Out:
# 1970.0    861
# 1960.0    720
# 1950.0    569
# 1980.0    336
# 1900.0    331
#          ...
# 1830.0      1
# 1854.0      1
# 1898.0      1
# 1901.0      1
# 1857.0      1
# Name: YearBuilt, Length: 144, dtype: int64

# %%
plt.figure(figsize=(12,8))
sb.scatterplot(x="YearBuilt",y="Price",data=df)
# Out:
# <AxesSubplot: xlabel='YearBuilt', ylabel='Price'>

# %% [markdown]
# # Removeing the Exceptions From the data

# %%
df = df[df["YearBuilt"]!=1196]

# %%
plt.figure(figsize=(12,8))
sb.scatterplot(x="YearBuilt",y="Price",data=df)
# Out:
# <AxesSubplot: xlabel='YearBuilt', ylabel='Price'>

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt        5284
# CouncilArea      1278
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df['YearBuilt'].fillna(value=1964, inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# YearBuilt           0
# CouncilArea      1278
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sb.scatterplot(y="CouncilArea",x="Price",data=df)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='CouncilArea'>

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Address', 'Type', 'Method', 'SellerG', 'Date', 'CouncilArea',
#        'Regionname'],
#       dtype='object')

# %%
df.drop("Address",axis=1,inplace=True)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Type', 'Method', 'SellerG', 'Date', 'CouncilArea',
#        'Regionname'],
#       dtype='object')

# %%
df['SellerG'].value_counts()
# Out:
# Nelson           1434
# Jellis           1172
# hockingstuart    1066
# Barry             876
# Ray               586
#                  ...
# Calder              1
# Parkinson           1
# Steveway            1
# Propertyau          1
# Bowman              1
# Name: SellerG, Length: 252, dtype: int64

# %%
df.drop("SellerG",axis=1,inplace=True)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Type', 'Method', 'Date', 'CouncilArea', 'Regionname'], dtype='object')

# %%
df["Type"].value_counts()
# Out:
# h    8095
# u    2961
# t    1045
# Name: Type, dtype: int64

# %%
dummies = pd.get_dummies(df['Type'],drop_first=True)
df = pd.concat([df.drop(["Type"],axis=1),dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Method', 'Date', 'CouncilArea', 'Regionname'], dtype='object')

# %%
df['Regionname'].value_counts()
# Out:
# Southern Metropolitan         4321
# Northern Metropolitan         3527
# Western Metropolitan          2615
# Eastern Metropolitan          1223
# South-Eastern Metropolitan     321
# Eastern Victoria                43
# Northern Victoria               26
# Western Victoria                25
# Name: Regionname, dtype: int64

# %%
dummies = pd.get_dummies(df['Regionname'],drop_first=True)
df = pd.concat([df.drop(["Regionname"],axis=1),dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Method', 'Date', 'CouncilArea'], dtype='object')

# %%
df['Date'].value_counts()
# Out:
# 27/05/2017    469
# 3/06/2017     390
# 12/08/2017    383
# 17/06/2017    370
# 27/11/2016    360
# 29/07/2017    339
# 4/03/2017     335
# 25/02/2017    328
# 24/06/2017    327
# 10/12/2016    318
# 22/07/2017    308
# 8/07/2017     307
# 18/03/2017    299
# 15/10/2016    298
# 12/11/2016    290
# 15/07/2017    290
# 3/12/2016     285
# 8/04/2017     276
# 1/07/2017     268
# 19/11/2016    265
# 18/06/2016    260
# 20/05/2017    259
# 28/05/2016    255
# 13/05/2017    251
# 8/10/2016     246
# 7/05/2016     244
# 17/09/2016    239
# 24/09/2016    239
# 28/08/2016    235
# 10/09/2016    233
# 16/04/2016    216
# 29/04/2017    216
# 4/06/2016     213
# 27/06/2016    208
# 3/09/2016     207
# 22/05/2016    201
# 7/11/2016     194
# 14/05/2016    193
# 22/08/2016    192
# 30/07/2016    168
# 6/08/2016     153
# 16/07/2016    140
# 6/05/2017     140
# 22/04/2017    134
# 26/07/2016    133
# 13/08/2016    132
# 23/04/2016    101
# 11/02/2017     84
# 12/06/2016     45
# 11/03/2017     38
# ...

# %%
df["Date_y"] = df["Date"].apply(lambda date: int(date.split('/')[2]))
df["Date_m"] = df["Date"].apply(lambda date:  int(date.split('/')[1]))

# %%
df.drop("Date",axis=1,inplace=True)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'Method', 'CouncilArea'], dtype='object')

# %%
df['Method'].value_counts()
# Out:
# S     8044
# SP    1525
# PI    1397
# VB    1054
# SA      81
# Name: Method, dtype: int64

# %%
dummies = pd.get_dummies(df['Method'],drop_first=True)
df = pd.concat([df.drop(["Method"],axis=1),dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb', 'CouncilArea'], dtype='object')

# %%
df["CouncilArea"].value_counts()
# Out:
# Boroondara           1153
# Moreland             1153
# Moonee Valley         986
# Darebin               922
# Glen Eira             844
# Stonnington           718
# Maribyrnong           682
# Yarra                 646
# Port Phillip          626
# Banyule               594
# Bayside               487
# Melbourne             470
# Hobsons Bay           422
# Brimbank              406
# Monash                329
# Manningham            310
# Whitehorse            300
# Kingston              206
# Whittlesea            166
# Hume                  159
# Wyndham                86
# Maroondah              80
# Knox                   79
# Melton                 66
# Frankston              52
# Greater Dandenong      51
# Casey                  37
# Nillumbik              36
# Yarra Ranges           18
# Cardinia                8
# Macedon Ranges          7
# Unavailable             1
# Moorabool               1
# Name: CouncilArea, dtype: int64

# %%
council = list(df["CouncilArea"].unique())
print(council)
# Out:
# ['Yarra', 'Moonee Valley', 'Port Phillip', 'Darebin', 'Hobsons Bay', 'Stonnington', 'Boroondara', 'Monash', 'Glen Eira', 'Whitehorse', 'Maribyrnong', 'Bayside', 'Moreland', 'Manningham', 'Banyule', 'Melbourne', 'Kingston', 'Brimbank', 'Hume', 'Knox', 'Maroondah', 'Casey', 'Melton', 'Greater Dandenong', 'Nillumbik', 'Whittlesea', 'Frankston', 'Macedon Ranges', 'Yarra Ranges', 'Wyndham', 'Cardinia', 'Unavailable', 'Moorabool']

# %%
for i in council:
    df.replace(to_replace=i,
           value=int(df[df['CouncilArea']==i].mean()["Price"]), inplace=True)
# Out:
# C:\Users\ANKIT\AppData\Local\Temp\ipykernel_37384\3905394337.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   value=int(df[df['CouncilArea']==i].mean()["Price"]), inplace=True)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['Suburb'], dtype='object')

# %%
sub = list(df["Suburb"].unique())
print(sub)
# Out:
# ['Abbotsford', 'Airport West', 'Albert Park', 'Alphington', 'Altona', 'Altona North', 'Armadale', 'Ascot Vale', 'Ashburton', 'Ashwood', 'Avondale Heights', 'Balaclava', 'Balwyn', 'Balwyn North', 'Bentleigh', 'Bentleigh East', 'Box Hill', 'Braybrook', 'Brighton', 'Brighton East', 'Brunswick', 'Brunswick West', 'Bulleen', 'Burwood', 'Camberwell', 'Canterbury', 'Carlton North', 'Carnegie', 'Caulfield', 'Caulfield North', 'Caulfield South', 'Chadstone', 'Clifton Hill', 'Coburg', 'Coburg North', 'Collingwood', 'Doncaster', 'Eaglemont', 'Elsternwick', 'Elwood', 'Essendon', 'Essendon North', 'Fairfield', 'Fitzroy', 'Fitzroy North', 'Flemington', 'Footscray', 'Glen Iris', 'Glenroy', 'Gowanbrae', 'Hadfield', 'Hampton', 'Hampton East', 'Hawthorn', 'Heidelberg Heights', 'Heidelberg West', 'Hughesdale', 'Ivanhoe', 'Kealba', 'Keilor East', 'Kensington', 'Kew', 'Kew East', 'Kooyong', 'Maidstone', 'Malvern', 'Malvern East', 805607, 925522, 'Middle Park', 'Mont Albert', 'Moonee Ponds', 'Moorabbin', 
# ...

# %%
1.075684e+06
# Out:
# 1075684.0

# %%
for i in sub:
    df.replace(to_replace=i,
           value=int(df[df['Suburb']==i].mean()["Price"])/1075684, inplace=True)
# Out:
# C:\Users\ANKIT\AppData\Local\Temp\ipykernel_37384\4252590480.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   value=int(df[df['Suburb']==i].mean()["Price"])/1075684, inplace=True)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index([], dtype='object')

# %%
X = df.drop("Price",axis=1).values
Y = df["Price"].values

# %%
df.columns
# Out:
# Index(['Suburb', 'Rooms', 'Price', 'Distance', 'Postcode', 'Bedroom2',
#        'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt',
#        'CouncilArea', 'Lattitude', 'Longtitude', 'Propertycount', 't', 'u',
#        'Eastern Victoria', 'Northern Metropolitan', 'Northern Victoria',
#        'South-Eastern Metropolitan', 'Southern Metropolitan',
#        'Western Metropolitan', 'Western Victoria', 'Date_y', 'Date_m', 'S',
#        'SA', 'SP', 'VB'],
#       dtype='object')

# %%
df.shape
# Out:
# (12101, 30)

# %% [markdown]
# ## Normalizing the Data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (9075, 29)

# %% [markdown]
# # Creating TensorFlow Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Implementing Early Stoping

# %%
early_stop = EarlyStopping(monitor="val_loss",mode="min",verbose=0,patience=25)

# %%
model = Sequential()

model.add(Dense(29,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(20,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(12,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(5,activation='relu'))
model.add(Dropout(0.1))

model.add(Dense(1))

model.compile(optimizer="adam",loss='mse')

# %%
model.fit(x=X_train,y=y_train,epochs=500,batch_size=25,validation_data=(X_test,y_test),
callbacks=[early_stop])
# Out:
# Epoch 1/500
# 363/363 [==============================] - 4s 4ms/step - loss: 1540327342080.0000 - val_loss: 1416676376576.0000
# Epoch 2/500
# 363/363 [==============================] - 1s 3ms/step - loss: 1061513723904.0000 - val_loss: 426092986368.0000
# Epoch 3/500
# 363/363 [==============================] - 1s 3ms/step - loss: 461769605120.0000 - val_loss: 338737037312.0000
# Epoch 4/500
# 363/363 [==============================] - 1s 4ms/step - loss: 423698595840.0000 - val_loss: 314890256384.0000
# Epoch 5/500
# 363/363 [==============================] - 1s 4ms/step - loss: 404814299136.0000 - val_loss: 295623000064.0000
# Epoch 6/500
# 363/363 [==============================] - 1s 4ms/step - loss: 385219002368.0000 - val_loss: 277798060032.0000
# Epoch 7/500
# 363/363 [==============================] - 1s 3ms/step - loss: 365269024768.0000 - val_loss: 258908389376.0000
# Epoch 8/500
# ...

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot: >

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
predictions = model.predict(X_test)
# Out:
# 95/95 [==============================] - 0s 1ms/step

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 201069.30065603313

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 324120.55970713333

# %%
explained_variance_score(y_test,predictions)
# Out:
# 0.7315702352254725

# %%
plt.scatter(y_test,predictions)
plt.plot(y_test,y_test,'r')

# %% [markdown]
# # Predicting on a Random House

# %%
import random

random_house = random.randint(0,len(df))

print(df.iloc[random_house]["Price"])

single_house = df.drop('Price',axis=1).iloc[random_house]
single_house = scaler.transform(single_house.values.reshape(-1, 29))
print(model.predict(single_house)[0])
# Out:
# 1100000.0
# 1/1 [==============================] - 0s 25ms/step
# [1084208.]

# %% [markdown]
# # Saving the Model

# %%
model.save("price_prediction_model")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: price_prediction_model\assets
# INFO:tensorflow:Assets written to: price_prediction_model\assets
